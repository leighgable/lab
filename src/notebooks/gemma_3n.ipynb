# %%
import jax
import penzai.pz as pz
import treescope

# %%
pz.ts.register_as_default()
pz.ts.register_autovisualize_magic()
pz.enable_interactive_context()
pz.ts.active_autovisualizer.set_interactive(pz.ts.ArrayAutovisualizer())

# %%
pz.ts.register_context_manager_magic()

# %%
from ..config import load_gemma_config
from ..build_blocks import build_gemma3n_transformer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ..config import load_gemma_config
#       2 from ..build_blocks import build_gemma3n_transformer
#
# ImportError: attempted relative import with no known parent package

# %%
conf_path = "/run/media/leigh/MEDIA/gemma_3n/"
config = load_gemma_config(conf_path)

# %%
transformer = build_gemma3n_transformer(config=config,
                                        init_base_rng=jax.random.key(123),
                                        name="hadamard"
                                       )

# %%
transformer.sub_layers

# %%
transformer

# %% [raw]
# !pwd
